# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-cf8f4601-b809-4594-a68c-510849f78c5f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cf8f4601-b809-4594-a68c-510849f78c5f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving SIMBAD_HD_226868_csv.csv to SIMBAD_HD_226868_csv.csv
# ...

# %%
import pandas as pd
import numpy as np  
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('classic')

# %%
data = pd.read_csv("SIMBAD_HD_226868_csv.csv")
data.head()
# Out:
#    _r ( arcsec )                  MAIN_ID  ... RAdeg ( deg ) DEdeg ( deg )
# 0         0.0000                HD 226868  ...    299.590316     35.201606
# 1        34.8943  2MASS J19582433+3511532  ...    299.601383     35.198117
# 2        35.5811  2MASS J19581917+3511476  ...    299.579911     35.196567
# 3        48.8067  2MASS J19582171+3512546  ...    299.590479     35.215163
# 4        54.9422             V* V1674 Cyg  ...    299.590157     35.216867
#
# [5 rows x 23 columns]

# %%
data.tail(10)
# Out:
#      _r ( arcsec )                      MAIN_ID  ... RAdeg ( deg ) DEdeg ( deg )
# 183       698.1223      2MASS J19591548+3515553  ...    299.814522     35.265390
# 184       701.8083      2MASS J19591889+3511406  ...    299.828729     35.194646
# 185       704.6861      2MASS J19591857+3513475  ...    299.827401     35.229867
# 186       705.8184  [MJD95] J195802.20+352310.4  ...    299.509542     35.386250
# 187       707.0593               TYC 2678-689-1  ...    299.350501     35.188613
# 188       707.4005               EXMS B1957+351  ...    299.804167     35.291667
# 189       708.6098      2MASS J19590142+3520407  ...    299.755930     35.344655
# 190       713.0658  [MJD95] J195918.89+351003.5  ...    299.829083     35.167667
# 191       715.6521      2MASS J19584038+3523237  ...    299.668264     35.389943
# 192       718.5889      2MASS J19591730+3508196  ...    299.822107     35.138820
#
# [10 rows x 23 columns]

# %%
import seaborn as sns
sns.set()

# %%
data.plot(x='_r ( arcsec )', y='V ( mag )', style='o')  
plt.title('Arc Sec vs V mag')  
plt.xlabel('Arc sec whatever shit this is')  
plt.ylabel('Whatever magnitude this is')  
plt.show()
sns.set()

# %%
data.plot(x='V ( mag )', y='B ( mag )', style='o')  
plt.title('V mag vs B mag')  
plt.xlabel('V mag')  
plt.ylabel('B mag')  
plt.show()
sns.set()

# %%
sns.heatmap(data.corr(),cmap='coolwarm')
plt.title('data.corr()')
# Out:
# Text(0.5, 1.0, 'data.corr()')

# %% [markdown]
# ## We can basically infer from here that most of the values are in the various magnitudes (whatever they are) others have mostly null values. LET'S GET A GOOD DATASET IF WE CAN
